# %% [markdown]
# LIST METHODS

# %%
#append->add the value at the last of the list
numbers=[10,20,30,40,50]
numbers.append(60)
print(numbers)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
#len():this function gives the length of the list
numbers=[10,20,30,40,50,60]
length=len(numbers)
print(length)
# Out:
# 6

# %%
#type():it gives type of the basic data type
numbers=[10,20,30,40,50,60]
type(numbers)
# Out:
# list

# %%
#update method:update the vlues using index method
numbers=[10,20,30,40,50,60]
numbers[2]=40
print(numbers)
# Out:
# [10, 20, 40, 40, 50, 60]

# %%
#index:it gives the index of the values
numbers.index(50)
# Out:
# 4

# %%
#remove():this method remove the specific item what we pass in the parantheses

numbers=[10,20,30,40,50,60]
numbers.remove(60)
print(numbers)
# Out:
# [10, 20, 30, 40, 50]

# %%
numbers=[10,20,30,40,50,60]
numbers.remove(60)
print(numbers)
# Out:
# [10, 20, 30, 40, 50]

# %%
#pop():thid method removes the last element of the list
numbers.pop()
# Out:
# 50

# %%
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
#insert():this method insert the item at the specific index and specific value
numbers=[10,20,30,40,50]
numbers.insert(3,35)
print(numbers)
# Out:
# [10, 20, 30, 35, 40, 50]

# %%
#extend():this method add the multiple values at the last of the list
numbers=[10,20,30,40,50]
numbers.extend([5,10,15,20])
print(numbers)
# Out:
# [10, 20, 30, 40, 50, 5, 10, 15, 20]

# %%
#append():this method add the another list inside the list as a output
numbers.append([15,25,35,45])
numbers
# Out:
# [10, 20, 30, 40, 50, 5, 10, 15, 20, [15, 25, 35, 45]]

# %%
#print the list inside the list with index
numbers[9]
# Out:
# [15, 25, 35, 45]

# %%
numbers[9][0]
# Out:
# 15

# %%
#sort():arranging the values in the ascending order
example=[2,1,5,4,7]
example.sort()
example
# Out:
# [1, 2, 4, 5, 7]

# %%
#reverse():print the items of the list in the descending order
example.reverse()
example
# Out:
# [7, 5, 4, 2, 1]

# %%
#copy():copy the items
new=example.copy()
new
# Out:
# [7, 5, 4, 2, 1]

# %%
#clear():clear all items present in the list
numbers.clear()
numbers
# Out:
# []

# %%
#indexing
numbers=[10,20,30,40,50]
print(numbers[0])
print(numbers[-1])
print(numbers[1:4])
# Out:
# 10
# 50
# [20, 30, 40]

# %% [markdown]
# TUPLE METHODS

# %%
#count():counting the values
numbers=(10,20,30,20)
print(numbers.count(20))
print(numbers.index(30))
print(numbers[1:3])
# Out:
# 2
# 2
# (20, 30)

# %%
#type
digits=(10,20,30,40)
print(digits)
print(type(digits))
print(len(digits))
print(sorted(numbers))
print(digits[0:2])
print(digits.count(10))
# Out:
# (10, 20, 30, 40)
# <class 'tuple'>
# 4
# [10, 20, 20, 30]
# (10, 20)
# 1

# %%
elements=(1,23,4,5,6,7,8,990)
print(elements)
print(type(elements))
print(len(elements))
print(sorted(elements))
print(elements.index(7))
print(elements[0:2])
print(elements.count(23))
# Out:
# (1, 23, 4, 5, 6, 7, 8, 990)
# <class 'tuple'>
# 8
# [1, 4, 5, 6, 7, 8, 23, 990]
# 5
# (1, 23)
# 1

# %%
#print the tuple values
digits=(1,23,4,5,6,7,8,990)
print(digits)
# Out:
# (1, 23, 4, 5, 6, 7, 8, 990)

# %%
#print the type of the basic data type
print(type(digits))
# Out:
# <class 'tuple'>

# %%
#len():print the length of the digits
print(len(digits))
# Out:
# 8

# %%
#sorting the values present in the tuple
sorted()
print(sorted(digits))
# Out:
# [1, 4, 5, 6, 7, 8, 23, 990]

# %%
#index():print the index of the value
print(digits.index(6))
# Out:
# 4

# %%
#count():count the value what user pass in the tuple
print(digits.count(8))
# Out:
# 1

# %%
#indexing
print(digits[0:3])
# Out:
# (1, 23, 4)

# %% [markdown]
# SET BASIC  DATA TYPE

# %%
#print the set values
set={10,20,30,40,50}
print(set)
# Out:
# {50, 20, 40, 10, 30}

# %%
#type():print the type of the set
print(type(set))
# Out:
# <class 'set'>

# %%
#add():this method add the number  in the set
set.add(60)
set
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
#len():print the length of the set
print(len(set))
# Out:
# 6

# %%
#update(): update the set values
set.update({60,90})
print(set)
# Out:
# {50, 20, 90, 40, 10, 60, 30}

# %%
#discard():discarding the value what user passed  in the parantheses
set.discard(60)
set
# Out:
# {10, 20, 30, 40, 50, 90}

# %%
print(20 in set)
# Out:
# True

# %%
#clear():remove the all items present in set
set.clear()
set
# Out:
# set()

# %%
set.clear()
set
# Out:
# set()

# %% [markdown]
# SET OPERATIONS

# %%
#union()
A={1,2,3,4,5,6,7,8}
B={2,4,6,8,9,4,6,9}
print(A|B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
#intersection()
print(A&B)
# Out:
# {8, 2, 4, 6}

# %%
#difference()
print(A-B)
# Out:
# {1, 3, 5, 7}

# %%
#symmetric difference
print(A^B)
# Out:
# {1, 3, 5, 7, 9}

# %% [markdown]
# DICTIONARY

# %%
#print the dictionary key and value pairs
student={
"name":"Rahul",
"age":22,
"course":"python"
}

print(student)
# Out:
# {'name': 'Rahul', 'age': 22, 'course': 'python'}

# %%
#type():print the type of the dictionary
print(type(student))
# Out:
# <class 'dict'>

# %%
#len():length of the dictionary
len(student)
student
# Out:
# {'name': 'Rahul', 'age': 22, 'course': 'python'}

# %%
#updateing the dict values by assigning the value to the key
student["grade"] = "A"
student
# Out:
# {'name': 'Rahul', 'age': 22, 'course': 'python', 'grade': 'A'}

# %%
#del this keyword del the specific key and value pair using key in the square braces
del student['course']
student
# Out:
# {'name': 'Rahul', 'age': 22, 'grade': 'A'}

# %%
#get():this method prints the value of the key
print(student.get('name'))
# Out:
# Rahul

# %%
print(student["age"])
# Out:
# 22

# %%
#pop():delete the specific value using key in parantheses
print(student.pop('age'))
# Out:
# 22

# %%
#copy():copy the items
dict=student.copy()
dict
# Out:
# {'name': 'Rahul', 'grade': 'A'}

# %%
#keys():print the keys
print(student.keys())
# Out:
# dict_keys(['name', 'grade'])

# %%
#values():print the values
print(student.values())
# Out:
# dict_values(['Rahul', 'A'])

# %%
#print the items present in the dictionary
print(student.items())
# Out:
# dict_items([('name', 'Rahul'), ('grade', 'A')])

# %%
#clear():print None
print(student.clear())
# Out:
# None

# %% [markdown]
# CONDITIONAL STATEMENTS

# %%
#if and else statement
a,b,c=150,-15,13
if a>b:
  if a>c:
    print("A is largest number")
  else:
    print("C is largest number")
else:
  if b>c:
    print("B is largest number")
  else:
    print("C is largest number")
# Out:
# A is largest number

# %%
#while condition
num=153
rem=0
sum=0
temp=num
while num>0:
  rem=num%10
  sum=sum+rem**3
  num=num//10
  if temp==sum:
    print("sum")
# Out:
# sum

# %%
#print the table of the number
num=4
i=1
while i<=10:
  print(num,"X",i,"=",num*i)
  i=i+1
# Out:
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
# 4 X 10 = 40
