# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Python 2nd pgm

# %%
print("*"*3)
# Out:
# ***

# %%
n=3
for i in range(n):
  print("*")
# Out:
# *
# *
# *

# %%
print("*" * 3,sep="\n")
# Out:
# ***

# %%
name="sanjana"
print(name)
# Out:
# sanjana
